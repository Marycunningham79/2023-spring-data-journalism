# %% [markdown]
# # NYC traffic accidents 2019-2020
# ## Filter and Subset

# %%
## import necessary libraries
import pandas as pd

# %%
## read the dataset into notebook
df = pd.read_csv("https://raw.githubusercontent.com/sandeepmj/datasets/main/nyc-accidents.csv")

# %%
## show the data frame
df

# %%
## see the overall info about this dataset
df.info()

# %%
## how many types of vehicles were the primary cause of the accidents
df1 = df["VEHICLE TYPE CODE 1"].value_counts
df1
# Out:
# <bound method IndexOpsMixin.value_counts of 0                �MBU
# 1                 Sedan
# 2                 Sedan
# 3                 Sedan
# 4                 Sedan
#               ...
# 324378        Ambulance
# 324379    Pick-up Truck
# 324380    Pick-up Truck
# 324381           Tanker
# 324382            Sedan
# Name: VEHICLE TYPE CODE 1, Length: 324383, dtype: object>

# %%
## correct answer
df1 = df["VEHICLE TYPE CODE 1"].nunique()
df1
# Out:
# 653

# %%
## how many types of vehicles were the primary cause of the accidents
df2=df["VEHICLE TYPE CODE 2"].value_counts()
df2
# Out:
# Sedan                                  103741
# Station Wagon/Sport Utility Vehicle     87780
# Taxi                                     9539
# Pick-up Truck                            8216
# Bike                                     8132
#                                         ...
# CMIX                                        1
# GLNEN                                       1
# EXCAVATOR                                   1
# US Postal                                   1
# G COM                                       1
# Name: VEHICLE TYPE CODE 2, Length: 711, dtype: int64

# %%
## which type of vehicle was primary vehicle involved in crashes?
## SHOW ONLY THE TOP 7
df1.head(7)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/b_/b10m0_vn5gdb__w26w1km08r0000gn/T/ipykernel_83809/3915474229.py in <module>
#       1 ## which type of vehicle was primary vehicle involved in crashes?
#       2 ## SHOW ONLY THE TOP 7
# ----> 3 df1.head(7)
#
# AttributeError: 'int' object has no attribute 'head'

# %%
df2.head(7)
# Out:
# Sedan                                  103741
# Station Wagon/Sport Utility Vehicle     87780
# Taxi                                     9539
# Pick-up Truck                            8216
# Bike                                     8132
# Box Truck                                7306
# Bus                                      4361
# Name: VEHICLE TYPE CODE 2, dtype: int64

# %%
## create a series of the crash dates.
df["CRASH DATE"]
# Out:
# 0          5/21/19
# 1          1/21/20
# 2         12/31/20
# 3         12/25/20
# 4          4/15/20
#             ...
# 324378      1/1/19
# 324379      1/1/19
# 324380      1/1/19
# 324381      1/1/19
# 324382      1/1/19
# Name: CRASH DATE, Length: 324383, dtype: object

# %%
## Which borough had the most crashes?
df["BOROUGH"].value_counts()
# Out:
# BROOKLYN         69944
# QUEENS           60529
# MANHATTAN        37446
# BRONX            36741
# STATEN ISLAND     6038
# Name: BOROUGH, dtype: int64

# %%
## What were a FIVE least encountered primary vehicles to get into a crash?
df["VEHICLE TYPE CODE 1"].value_counts().tail(5)
# Out:
# Ford sprin    1
# e skate bo    1
# NYC AMBULA    1
# MOTOR SCOO    1
# MAC T         1
# Name: VEHICLE TYPE CODE 1, dtype: int64

# %%
## create a subset of data for only Queens
## place it in a dataframe called df_q
df_q = df.query("BOROUGH == 'QUEENS'")
df_q
# Out:
#        CRASH DATE CRASH TIME BOROUGH                 LOCATION  \
# 15         5/2/20      17:30  QUEENS    (40.67376, -73.79473)
# 74       12/16/20      16:20  QUEENS      (40.7139, -73.7539)
# 97         6/4/20       7:30  QUEENS  (40.744232, -73.861275)
# 105       12/3/20      15:10  QUEENS                      NaN
# 129      12/19/20      16:15  QUEENS    (40.72362, -73.88802)
# ...           ...        ...     ...                      ...
# 324366     1/1/19      11:00  QUEENS   (40.698704, -73.89974)
# 324367     1/1/19      12:30  QUEENS    (40.74114, -73.85747)
# 324371     1/1/19       2:18  QUEENS   (40.716507, -73.84711)
# 324372     1/1/19      13:00  QUEENS   (40.665497, -73.75573)
# 324375     1/1/19      10:23  QUEENS    (40.75868, -73.87552)
#
#         NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 15                              0                         0
# 74                              0                         0
# 97                              0                         0
# 105                             0                         0
# 129                             1                         0
# ...                           ...                       ...
# 324366                          0                         0
# 324367                          0                         0
# 324371                          0                         0
# 324372                          0                         0
# 324375                          1                         0
#
#         NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# 15                                  0                             0
# 74                                  0                             0
# 97                                  0                             0
# 105                                 0                             0
# 129                                 1                             0
# ...                               ...                           ...
# 324366                              0                             0
# 324367                              0                             0
# 324371                              0                             0
# 324372                              0                             0
# 324375                              0                             0
#
#         NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# 15                              0                         0
# 74                              0                         0
# 97                              0                         0
# 105                             0                         0
# 129                             0                         0
# ...                           ...                       ...
# 324366                          0                         0
# 324367                          0                         0
# 324371                          0                         0
# 324372                          0                         0
# 324375                          0                         0
#
#         NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED  \
# 15                               0                          0
# 74                               0                          0
# 97                               0                          0
# 105                              0                          0
# 129                              0                          0
# ...                            ...                        ...
# 324366                           0                          0
# 324367                           0                          0
# 324371                           0                          0
# 324372                           0                          0
# 324375                           1                          0
#
#          CONTRIBUTING FACTOR VEHICLE 1 CONTRIBUTING FACTOR VEHICLE 2  \
# 15                Unsafe Lane Changing                   Unspecified
# 74                 Driver Inexperience                           NaN
# 97                         Unspecified                   Unspecified
# 105     Passing or Lane Usage Improper                   Unspecified
# 129                   Backing Unsafely                           NaN
# ...                                ...                           ...
# 324366                     Unspecified                           NaN
# 324367                     Unspecified                           NaN
# 324371                     Unspecified                   Unspecified
# 324372                     Unspecified                   Unspecified
# 324375           Failure to Keep Right         Failure to Keep Right
#
#         COLLISION_ID                  VEHICLE TYPE CODE 1  \
# 15           4412513  Station Wagon/Sport Utility Vehicle
# 74           4376676                            Box Truck
# 97           4423984                                  Bus
# 105          4373032                                Sedan
# 129          4379293  Station Wagon/Sport Utility Vehicle
# ...              ...                                  ...
# 324366       4065827                                Sedan
# 324367       4062343                                Sedan
# 324371       4060413                                Sedan
# 324372       4060511                                Sedan
# 324375       4059208  Station Wagon/Sport Utility Vehicle
#
#                         VEHICLE TYPE CODE 2
# 15                            Pick-up Truck
# 74                                      NaN
# 97      Station Wagon/Sport Utility Vehicle
# 105                                     NaN
# 129                                     NaN
# ...                                     ...
# 324366                                  NaN
# 324367                                  NaN
# 324371                                  NaN
# 324372                                Sedan
# 324375                                Sedan
#
# [60529 rows x 17 columns]

# %%
## How many people were killed in Queens in accidents?
df_q["NUMBER OF PERSONS KILLED"].value_counts()
# Out:
# 0    60446
# 1       80
# 2        2
# 3        1
# Name: NUMBER OF PERSONS KILLED, dtype: int64

# %%
## Count of
## How many rows are there of people killed in Queens
df_q["NUMBER OF PERSONS KILLED"].count()
# Out:
# 60529

# %%
df_q["NUMBER OF PERSONS KILLED"].sum()
# Out:
# 87

# %%
## how many cyclists were killed in Queens?

df_q["NUMBER OF CYCLIST KILLED"].value_counts()
# Out:
# 0    60523
# 1        6
# Name: NUMBER OF CYCLIST KILLED, dtype: int64

# %% [markdown]
# **Syntax for querying multi-word column names:**
#
# ```dataframe.query('`column name` comparison_operator value')```
#
# Note the opening and closing tick marks ``` ` ```

# %%
## create a dataset for Manhattan AND TAXIS only
df.query("BOROUGH == 'MANHATTAN' & (`VEHICLE TYPE CODE 1` == 'Taxi' | `VEHICLE TYPE CODE 2` == 'Taxi')")
# Out:
#        CRASH DATE CRASH TIME    BOROUGH                 LOCATION  \
# 343      12/22/20      23:55  MANHATTAN    (40.78911, -73.96656)
# 528      12/17/20       3:40  MANHATTAN   (40.821636, -73.93909)
# 697      12/23/20      21:38  MANHATTAN     (40.8188, -73.95603)
# 1163     12/17/20      16:45  MANHATTAN   (40.74147, -73.985435)
# 1286     12/22/20       0:00  MANHATTAN   (40.763363, -73.95925)
# ...           ...        ...        ...                      ...
# 324094     1/2/19       8:38  MANHATTAN  (40.752724, -73.996796)
# 324261     1/1/19      16:15  MANHATTAN   (40.741524, -73.97979)
# 324296     1/1/19      20:30  MANHATTAN   (40.821636, -73.93909)
# 324328     1/1/19       4:00  MANHATTAN    (40.86446, -73.91895)
# 324353     1/1/19       6:00  MANHATTAN    (40.76161, -73.97076)
#
#         NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 343                             1                         0
# 528                             0                         0
# 697                             1                         0
# 1163                            0                         0
# 1286                            0                         0
# ...                           ...                       ...
# 324094                          0                         0
# 324261                          0                         0
# 324296                          0                         0
# 324328                          1                         0
# 324353                          0                         0
#
#         NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# 343                                 1                             0
# 528                                 0                             0
# 697                                 1                             0
# 1163                                0                             0
# 1286                                0                             0
# ...                               ...                           ...
# 324094                              0                             0
# 324261                              0                             0
# 324296                              0                             0
# 324328                              0                             0
# 324353                              0                             0
#
#         NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# 343                             0                         0
# 528                             0                         0
# 697                             0                         0
# 1163                            0                         0
# 1286                            0                         0
# ...                           ...                       ...
# 324094                          0                         0
# 324261                          0                         0
# 324296                          0                         0
# 324328                          0                         0
# 324353                          0                         0
#
#         NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED  \
# 343                              0                          0
# 528                              0                          0
# 697                              0                          0
# 1163                             0                          0
# 1286                             0                          0
# ...                            ...                        ...
# 324094                           0                          0
# 324261                           0                          0
# 324296                           0                          0
# 324328                           1                          0
# 324353                           0                          0
#
#          CONTRIBUTING FACTOR VEHICLE 1 CONTRIBUTING FACTOR VEHICLE 2  \
# 343                        Unspecified                           NaN
# 528        Traffic Control Disregarded                   Unspecified
# 697      Failure to Yield Right-of-Way                           NaN
# 1163    Driver Inattention/Distraction                   Unspecified
# 1286    Reaction to Uninvolved Vehicle                   Unspecified
# ...                                ...                           ...
# 324094           Following Too Closely                   Unspecified
# 324261           Passenger Distraction           Passing Too Closely
# 324296                     Unspecified                           NaN
# 324328             Alcohol Involvement                   Unspecified
# 324353                     Unspecified                           NaN
#
#         COLLISION_ID                  VEHICLE TYPE CODE 1 VEHICLE TYPE CODE 2
# 343          4378322                                 Taxi                 NaN
# 528          4377075                                 Taxi                 NaN
# 697          4378603                                 Taxi                 NaN
# 1163         4376897                                  Bus                Taxi
# 1286         4378159  Station Wagon/Sport Utility Vehicle                Taxi
# ...              ...                                  ...                 ...
# 324094       4061330                                  Bus                Taxi
# 324261       4060796                                 Taxi               Sedan
# 324296       4060662                                 Taxi                 NaN
# 324328       4061250                                Sedan                Taxi
# 324353       4060698                                 Taxi                 NaN
#
# [7316 rows x 17 columns]

# %%
## What were the top 8 causes of accidents across all the boroughs?
## by primary vehicle cause
df["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().head(8)
# Out:
# Driver Inattention/Distraction    83809
# Unspecified                       78621
# Following Too Closely             26689
# Failure to Yield Right-of-Way     21943
# Backing Unsafely                  13497
# Passing or Lane Usage Improper    13406
# Passing Too Closely               12649
# Other Vehicular                    9646
# Name: CONTRIBUTING FACTOR VEHICLE 1, dtype: int64

# %%
## What were the top 8 causes of accidents across all the boroughs?
## by secondary vehicle cause
df["CONTRIBUTING FACTOR VEHICLE 2"].value_counts().head(8)
# Out:
# Unspecified                       221742
# Driver Inattention/Distraction     18105
# Following Too Closely               4507
# Other Vehicular                     4268
# Passing or Lane Usage Improper      2919
# Failure to Yield Right-of-Way       2522
# Passing Too Closely                 2124
# Unsafe Lane Changing                1502
# Name: CONTRIBUTING FACTOR VEHICLE 2, dtype: int64

# %%
## What were the 5 fewest causes for primary vehicles causing the accident
df["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().tail(5)
# Out:
# Cell Phone (hands-free)         16
# Shoulders Defective/Improper    14
# Texting                          6
# Windshield Inadequate            5
# Listening/Using Headphones       5
# Name: CONTRIBUTING FACTOR VEHICLE 1, dtype: int64

# %% [markdown]
# ##  DON'T DO THE ONES BELOW
# I did not cover it yet

# %%
## How many unique values are there for primary reasons for accidents

# %%
## list ALL the causes as unique values (in other words, create a list of the causes)
