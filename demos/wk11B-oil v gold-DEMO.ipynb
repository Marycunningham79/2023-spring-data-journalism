# %% [markdown]
# # Oil v. Gold Comparison
#
# You want to compare the monthly closing price of gold v. oil over the past decade.
#
# The easiest way to uncover a pattern will be to line graph the data
#
# The data can be [found here](https://drive.google.com/file/d/122tdS2eTZEq9q7bbKEZMf6168Vi8biRh/view?usp=share_link).

# %%
import pandas as pd

# %%
df_raw = pd.read_csv("oil-v-gold.csv")
df_raw
# Out:
#     GC1 Comdty (Gold) Unnamed: 1  Unnamed: 2 CL1 Comdty (Oil) Unnamed: 4
# 0                Date    PX_LAST         NaN             Date    PX_LAST
# 1           1/31/2008      922.7         NaN        1/31/2008      91.75
# 2           2/29/2008        975         NaN        2/29/2008     101.84
# 3           3/31/2008      916.2         NaN        3/31/2008     101.58
# 4           4/30/2008      865.1         NaN        4/30/2008     113.46
# ..                ...        ...         ...              ...        ...
# 117         9/29/2017     1281.5         NaN        9/29/2017      51.67
# 118        10/31/2017     1270.5         NaN       10/31/2017      54.38
# 119        11/30/2017     1273.2         NaN       11/30/2017       57.4
# 120        12/29/2017     1309.3         NaN       12/29/2017      60.42
# 121         1/31/2018       1339         NaN        1/31/2018      64.73
#
# [122 rows x 5 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GC1 Comdty (Gold)  122 non-null    object
#  1   Unnamed: 1         122 non-null    object
#  2   Unnamed: 2         0 non-null      float64
#  3   CL1 Comdty (Oil)   122 non-null    object
#  4   Unnamed: 4         122 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 4.9+ KB

# %%
df_raw
# Out:
#     GC1 Comdty (Gold) Unnamed: 1  Unnamed: 2 CL1 Comdty (Oil) Unnamed: 4
# 0                Date    PX_LAST         NaN             Date    PX_LAST
# 1           1/31/2008      922.7         NaN        1/31/2008      91.75
# 2           2/29/2008        975         NaN        2/29/2008     101.84
# 3           3/31/2008      916.2         NaN        3/31/2008     101.58
# 4           4/30/2008      865.1         NaN        4/30/2008     113.46
# ..                ...        ...         ...              ...        ...
# 117         9/29/2017     1281.5         NaN        9/29/2017      51.67
# 118        10/31/2017     1270.5         NaN       10/31/2017      54.38
# 119        11/30/2017     1273.2         NaN       11/30/2017       57.4
# 120        12/29/2017     1309.3         NaN       12/29/2017      60.42
# 121         1/31/2018       1339         NaN        1/31/2018      64.73
#
# [122 rows x 5 columns]

# %% [markdown]
# ## What is our approach? (pseudocode)

# %%
# Fix It
##Drop Duplicates and nan values
##Convert objects into floating point numbers
#Drop column names, provide sensical 
##Rename gold and oil columns

# %%
## drop dupes
df_raw.columns
# Out:
# Index(['GC1 Comdty (Gold)', 'Unnamed: 1', 'Unnamed: 2', 'CL1 Comdty (Oil)',
#        'Unnamed: 4'],
#       dtype='object')

# %%
df = df_raw[['GC1 Comdty (Gold)', 'Unnamed: 1',
       'Unnamed: 4']]
df
# Out:
#     GC1 Comdty (Gold) Unnamed: 1 Unnamed: 4
# 0                Date    PX_LAST    PX_LAST
# 1           1/31/2008      922.7      91.75
# 2           2/29/2008        975     101.84
# 3           3/31/2008      916.2     101.58
# 4           4/30/2008      865.1     113.46
# ..                ...        ...        ...
# 117         9/29/2017     1281.5      51.67
# 118        10/31/2017     1270.5      54.38
# 119        11/30/2017     1273.2       57.4
# 120        12/29/2017     1309.3      60.42
# 121         1/31/2018       1339      64.73
#
# [122 rows x 3 columns]

# %%
df_raw.sample(20)
# Out:
#     GC1 Comdty (Gold) Unnamed: 1  Unnamed: 2 CL1 Comdty (Oil) Unnamed: 4
# 101         5/31/2016     1214.8         NaN        5/31/2016       49.1
# 93          9/30/2015     1115.5         NaN        9/30/2015      45.09
# 49          1/31/2012     1737.8         NaN        1/31/2012      98.48
# 17          5/29/2009      978.8         NaN        5/29/2009      66.31
# 35         11/30/2010       1385         NaN       11/30/2010      84.11
# 69          9/30/2013     1326.5         NaN        9/30/2013     102.33
# 58         10/31/2012     1719.1         NaN       10/31/2012      86.24
# 2           2/29/2008        975         NaN        2/29/2008     101.84
# 29          5/31/2010     1212.2         NaN        5/31/2010      73.97
# 83         11/28/2014     1175.2         NaN       11/28/2014      66.15
# 80          8/29/2014     1286.5         NaN        8/29/2014      95.96
# 115         7/31/2017     1266.6         NaN        7/31/2017      50.17
# 0                Date    PX_LAST         NaN             Date    PX_LAST
# 60         12/31/2012     1675.8         NaN       12/31/2012      91.82
# 106        10/31/2016     1273.1         NaN       10/31/2016      46.86
# 9           9/30/2008      874.2         NaN        9/30/2008     100.64
# 37          1/31/2011     1333.8         NaN        1/31/2011      92.19
# 13          1/30/2009      927.3         NaN        1/30/2009      41.68
# 33          9/30/2010     1307.8         NaN        9/30/2010      79.97
# 20          8/31/2009      952.2         NaN        8/31/2009      69.96

# %%
## rename column headers
df.columns = ["closing_date", "px_gold", "px_oil"]
df
# Out:
#     closing_date  px_gold   px_oil
# 0           Date  PX_LAST  PX_LAST
# 1      1/31/2008    922.7    91.75
# 2      2/29/2008      975   101.84
# 3      3/31/2008    916.2   101.58
# 4      4/30/2008    865.1   113.46
# ..           ...      ...      ...
# 117    9/29/2017   1281.5    51.67
# 118   10/31/2017   1270.5    54.38
# 119   11/30/2017   1273.2     57.4
# 120   12/29/2017   1309.3    60.42
# 121    1/31/2018     1339    64.73
#
# [122 rows x 3 columns]

# %%
## reset index
## delete top row
df = df.drop(0).reset_index(drop = True)
df
# Out:
#     closing_date px_gold  px_oil
# 0      2/29/2008     975  101.84
# 1      3/31/2008   916.2  101.58
# 2      4/30/2008   865.1  113.46
# 3      5/30/2008   887.3  127.35
# 4      6/30/2008   928.3     140
# ..           ...     ...     ...
# 115    9/29/2017  1281.5   51.67
# 116   10/31/2017  1270.5   54.38
# 117   11/30/2017  1273.2    57.4
# 118   12/29/2017  1309.3   60.42
# 119    1/31/2018    1339   64.73
#
# [120 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   closing_date  120 non-null    object
#  1   px_gold       120 non-null    object
#  2   px_oil        120 non-null    object
# dtypes: object(3)
# memory usage: 2.9+ KB

# %%
## convert to floating point numbers gold
df["px_gold"] = pd.to_numeric(df["px_gold"], errors = "coerce")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   closing_date  120 non-null    object
#  1   px_gold       120 non-null    float64
#  2   px_oil        120 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 2.9+ KB

# %%
## convert to floating point numbers oil
df["px_oil"] = pd.to_numeric(df["px_oil"], errors = "coerce")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   closing_date  120 non-null    object
#  1   px_gold       120 non-null    float64
#  2   px_oil        120 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 2.9+ KB

# %%
df
# Out:
#     closing_date  px_gold  px_oil
# 0      2/29/2008    975.0  101.84
# 1      3/31/2008    916.2  101.58
# 2      4/30/2008    865.1  113.46
# 3      5/30/2008    887.3  127.35
# 4      6/30/2008    928.3  140.00
# ..           ...      ...     ...
# 115    9/29/2017   1281.5   51.67
# 116   10/31/2017   1270.5   54.38
# 117   11/30/2017   1273.2   57.40
# 118   12/29/2017   1309.3   60.42
# 119    1/31/2018   1339.0   64.73
#
# [120 rows x 3 columns]

# %%
df.to_csv("oil-v-gold-export.csv", index = False, encoding ="UTF8")

# %%
df.plot(x = "closing_date",
       y = ["px_gold", "px_oil"])
# Out:
# <AxesSubplot:xlabel='closing_date'>

# %%
## pct change calculation for gold using iat
old_gold = df["px_gold"].iat[0]
old_gold
# Out:
# 975.0

# %%
df["gold_pct_chg"] = \
((df["px_gold"] - old_gold) / old_gold) *100
df
# Out:
#     closing_date  px_gold  px_oil  gold_pct_chg
# 0      2/29/2008    975.0  101.84      0.000000
# 1      3/31/2008    916.2  101.58     -6.030769
# 2      4/30/2008    865.1  113.46    -11.271795
# 3      5/30/2008    887.3  127.35     -8.994872
# 4      6/30/2008    928.3  140.00     -4.789744
# ..           ...      ...     ...           ...
# 115    9/29/2017   1281.5   51.67     31.435897
# 116   10/31/2017   1270.5   54.38     30.307692
# 117   11/30/2017   1273.2   57.40     30.584615
# 118   12/29/2017   1309.3   60.42     34.287179
# 119    1/31/2018   1339.0   64.73     37.333333
#
# [120 rows x 4 columns]

# %%
old_oil = df["px_oil"].iat[0]
old_oil
# Out:
# 101.84

# %%
df["oil_pct_chg"] = \
((df["px_oil"] - old_oil) / old_oil) *100
df
# Out:
#     closing_date  px_gold  px_oil  gold_pct_chg  oil_pct_chg
# 0      2/29/2008    975.0  101.84      0.000000     0.000000
# 1      3/31/2008    916.2  101.58     -6.030769    -0.255302
# 2      4/30/2008    865.1  113.46    -11.271795    11.410055
# 3      5/30/2008    887.3  127.35     -8.994872    25.049097
# 4      6/30/2008    928.3  140.00     -4.789744    37.470542
# ..           ...      ...     ...           ...          ...
# 115    9/29/2017   1281.5   51.67     31.435897   -49.263551
# 116   10/31/2017   1270.5   54.38     30.307692   -46.602514
# 117   11/30/2017   1273.2   57.40     30.584615   -43.637078
# 118   12/29/2017   1309.3   60.42     34.287179   -40.671642
# 119    1/31/2018   1339.0   64.73     37.333333   -36.439513
#
# [120 rows x 5 columns]

# %%
## basic line graph
df.plot(x = "closing_date", 
y = ["oil_pct_chg", "gold_pct_chg"])
# Out:
# <AxesSubplot:xlabel='closing_date'>

# %%
## add a title

df.plot(x = "closing_date", 
y = ["oil_pct_chg", "gold_pct_chg"],
       title = "Oil v. Gold Over Time")
# Out:
# <AxesSubplot:title={'center':'Oil v. Gold Over Time'}, xlabel='closing_date'>

# %%
##why is gold orange and oil blue?

df.plot(x = "closing_date", 
y = ["oil_pct_chg", "gold_pct_chg"],
       title = "Oil v. Gold Over Time",
      style = {"oil_pct_chg": "gray",
              "gold_pct_chg": "gold"})
# Out:
# <AxesSubplot:title={'center':'Oil v. Gold Over Time'}, xlabel='closing_date'>
